# %%
import LIF as lif


neuron = lif.LIFNeuron()

print(neuron.getV_Reset())
neuron.setV_Reset(-60e-3)
print(neuron.getV_Reset())

vMFig, IFig = lif.LIFNeuron.modelNeuron(neuron)
# Out:
# -0.07
# 20
